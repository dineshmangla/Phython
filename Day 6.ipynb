# %%
import numpy
a=numpy.array([1,2,3])
a
type(a)

# %%
import numpy
lhs=numpy.mat([[2,-4,5],[3,-3,6],[8,-4,-3]])
rhs=numpy.mat([[10],[12],[11]])
ans=lhs.I* rhs
print(ans)

# %%
import numpy
arr=numpy.array([10,22,33,11,9,7,3,4,5,2])
list1=[2,5,7]
arr[list1]

# %%
import numpy
arr=numpy.array([10,20,30])
arr2=arr.copy()
arr2[0]=100
arr2

# %%
import numpy
arr=numpy.array([1,2,3,4])
arr1=arr.view()
arr1[0]=20
arr
arr1

# %%
import pandas
class Emp():
    def Create_d(self):
        d={}
        empid_list=[]
        empname_list=[]
        empid=int(input("enter the empid " ))
        while empid != -999:
            empid_list.append(empid)
            empid=int(input("enter the empid " ))
        print(empid_list)
        num=1
        count=len(empid_list)
        while count >=1:
            empname_list.append(input("enter emp name  "))
            count-=1
        print(empname_list)
        d['empid']=empid_list
        d['name']=empname_list
        return d
obj=Emp()   
d=obj.Create_d()
df=pandas.dataframe(d) 
print(df)

# %%
import numpy
x=numpy.arange(0,5,0.01)
import matplotlib.pylab as plt
plt.plot(x , [x1**2 for x1 in x])
plt.plot(x , [x1**3 for x1 in x])
plt.plot(x , [x1 for x1 in x])
plt.plot(x , [x1 for x1 in x],x , [x1**2 for x1 in x],x , [x1**3 for x1 in x])
plt.grid(True)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("relationship between x and y")
plt.xlim(-1,5)
plt.ylim(-1,10)
plt.ylim(-1,10)
plt.show()

# %%
import numpy
x=numpy.arange(5)
import matplotlib.pylab as plt
plt.plot(x,x ,label ='Linear')
plt.plot(x,x**2 ,label ='Square')
plt.plot(x,x**3 ,label ='Cube')
plt.grid(True)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("relationship between x and y")
plt.legend()
plt.savefig('C:\\Users\\dinesh135732\\Desktop\\phython\\myfile.png')
plt.show()
